# %% [markdown]
# # Ford GoBike System Data Exploration
# ## by (Acheampong Andrews)
#
# ## Introduction
# > This data set includes information about individual rides made in a bike-sharing system covering the greater San Francisco Bay area.
#
# ## Preliminary Wrangling

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %%
df_bike = pd.read_csv('201902-fordgobike-tripdata.csv')
df_bike.head(10)
# Out:
#    duration_sec                start_time                  end_time  \
# 0         52185  2019-02-28 17:32:10.1450  2019-03-01 08:01:55.9750
# 1         42521  2019-02-28 18:53:21.7890  2019-03-01 06:42:03.0560
# 2         61854  2019-02-28 12:13:13.2180  2019-03-01 05:24:08.1460
# 3         36490  2019-02-28 17:54:26.0100  2019-03-01 04:02:36.8420
# 4          1585  2019-02-28 23:54:18.5490  2019-03-01 00:20:44.0740
# 5          1793  2019-02-28 23:49:58.6320  2019-03-01 00:19:51.7600
# 6          1147  2019-02-28 23:55:35.1040  2019-03-01 00:14:42.5880
# 7          1615  2019-02-28 23:41:06.7660  2019-03-01 00:08:02.7560
# 8          1570  2019-02-28 23:41:48.7900  2019-03-01 00:07:59.7150
# 9          1049  2019-02-28 23:49:47.6990  2019-03-01 00:07:17.0250
#
#    start_station_id                                start_station_name  \
# 0              21.0  Montgomery St BART Station (Market St at 2nd St)
# 1              23.0                     The Embarcadero at Steuart St
# ...

# %%
df_bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183412 entries, 0 to 183411
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             183412 non-null  int64
#  1   start_time               183412 non-null  object
#  2   end_time                 183412 non-null  object
#  3   start_station_id         183215 non-null  float64
#  4   start_station_name       183215 non-null  object
#  5   start_station_latitude   183412 non-null  float64
#  6   start_station_longitude  183412 non-null  float64
#  7   end_station_id           183215 non-null  float64
#  8   end_station_name         183215 non-null  object
#  9   end_station_latitude     183412 non-null  float64
#  10  end_station_longitude    183412 non-null  float64
#  11  bike_id                  183412 non-null  int64
#  12  user_type                183412 non-null  object
# ...

# %% [markdown]
# > Splitting the date and time in the start_time and end_time columns into a different columns

# %%
import datetime
df_bike['start_time'] = pd.to_datetime(df_bike['start_time'])
df_bike['end_time'] = pd.to_datetime(df_bike['end_time'])

# %%
df_bike['stat_tim'] = [d.time() for d in df_bike['start_time']]
df_bike['end_tim'] = [d.time() for d in df_bike['end_time']]
df_bike['start_date'] = [d.date() for d in df_bike['start_time']]
df_bike['end_date'] = [d.date() for d in df_bike['end_time']]
df_bike.drop(['start_time', 'end_time'], axis = 1, inplace = True)

# %%
df_bike.rename(columns={'stat_tim':'start_time', 'end_tim': 'end_time'}, inplace = True)

# %%
df_bike = df_bike[['duration_sec',
 'start_time',
 'end_time',
 'start_date',
 'end_date',
 'start_station_id',
 'start_station_name',
 'start_station_latitude',
 'start_station_longitude',
 'end_station_id',
 'end_station_name',
 'end_station_latitude',
 'end_station_longitude',
 'bike_id',
 'user_type',
 'member_birth_year',
 'member_gender',
 'bike_share_for_all_trip',
 ]]
df_bike.head(10)
# Out:
#    duration_sec       start_time         end_time  start_date    end_date  \
# 0         52185  17:32:10.145000  08:01:55.975000  2019-02-28  2019-03-01
# 1         42521  18:53:21.789000  06:42:03.056000  2019-02-28  2019-03-01
# 2         61854  12:13:13.218000  05:24:08.146000  2019-02-28  2019-03-01
# 3         36490  17:54:26.010000  04:02:36.842000  2019-02-28  2019-03-01
# 4          1585  23:54:18.549000  00:20:44.074000  2019-02-28  2019-03-01
# 5          1793  23:49:58.632000  00:19:51.760000  2019-02-28  2019-03-01
# 6          1147  23:55:35.104000  00:14:42.588000  2019-02-28  2019-03-01
# 7          1615  23:41:06.766000  00:08:02.756000  2019-02-28  2019-03-01
# 8          1570  23:41:48.790000  00:07:59.715000  2019-02-28  2019-03-01
# 9          1049  23:49:47.699000  00:07:17.025000  2019-02-28  2019-03-01
#
#    start_station_id                                start_station_name  \
# 0              21.0  Montgomery St BART Station (Market St at 2nd St)
# ...

# %% [markdown]
# > Removing rows that contain no content

# %%
df_bike = df_bike.dropna().reset_index(drop=True)
df_bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174952 entries, 0 to 174951
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             174952 non-null  int64
#  1   start_time               174952 non-null  object
#  2   end_time                 174952 non-null  object
#  3   start_date               174952 non-null  object
#  4   end_date                 174952 non-null  object
#  5   start_station_id         174952 non-null  float64
#  6   start_station_name       174952 non-null  object
#  7   start_station_latitude   174952 non-null  float64
#  8   start_station_longitude  174952 non-null  float64
#  9   end_station_id           174952 non-null  float64
#  10  end_station_name         174952 non-null  object
#  11  end_station_latitude     174952 non-null  float64
#  12  end_station_longitude    174952 non-null  float64
# ...

# %%
df_bike.shape
# Out:
# (174952, 18)

# %%
df_bike.dtypes
# Out:
# duration_sec                 int64
# start_time                  object
# end_time                    object
# start_date                  object
# end_date                    object
# start_station_id           float64
# start_station_name          object
# start_station_latitude     float64
# start_station_longitude    float64
# end_station_id             float64
# end_station_name            object
# end_station_latitude       float64
# end_station_longitude      float64
# bike_id                      int64
# user_type                   object
# member_birth_year          float64
# member_gender               object
# bike_share_for_all_trip     object
# dtype: object

# %% [markdown]
# ### What is the structure of your dataset?
#
# >  There are 174952 entries in the dataset with 18 columns (duration_sec, start_time, end_time, start_date, end_date, start_station_id, start_station_name, start_station_latitude, start_station_longitude, end_station_id, end_station_name, end_station_latitude, end_station_longitude, bike_id, user_type, member_birth_year	member_gender and bike_share_for_all_trip ).
#
# ### What is/are the main feature(s) of interest in your dataset?
#
# > I'm most interested in figuring out how long does the average trip takes.
#
# ### What features in the dataset do you think will help support your investigation into your feature(s) of interest?
#
# > I expect that duration_sec will have the strongest effect on each bike_id: the smallest the duration_sec, the faster the bike_id. I will also look into the gender column, to see the average fasters gender in the dataset.

# %% [markdown]
# ## Univariate Exploration
#
# > In this section I will start looking at the distribution of the variables of interest.

# %%
plt.figure(figsize = [5, 10])


def_color = sb.color_palette()[0]
plt.subplot(3, 1, 1)
sb.countplot(data = df_bike, x = 'user_type', color = def_color, );

plt.subplot(3, 1, 2)
sb.countplot(data = df_bike, x = 'member_gender', color = def_color,);

plt.subplot(3, 1, 3)
sb.countplot(data = df_bike, x = 'bike_share_for_all_trip', color = def_color,);

# %% [markdown]
# The user type in the bike dataset is either a customer or a subscriber, with most of them in the subscriber level. Most of the bike dataset are also of male member gender. Bike share for all trip, shows that most of the bike were not shared.
#
# I'll now look at the other features in the data to see if any of them hold interesting properties.

# %%
df_bike.describe()
# Out:
#         duration_sec  start_station_id  start_station_latitude  \
# count  174952.000000     174952.000000           174952.000000
# mean      704.002744        139.002126               37.771220
# std      1642.204905        111.648819                0.100391
# min        61.000000          3.000000               37.317298
# 25%       323.000000         47.000000               37.770407
# 50%       510.000000        104.000000               37.780760
# 75%       789.000000        239.000000               37.797320
# max     84548.000000        398.000000               37.880222
#
#        start_station_longitude  end_station_id  end_station_latitude  \
# count            174952.000000   174952.000000         174952.000000
# mean               -122.351760      136.604486             37.771414
# std                   0.117732      111.335635              0.100295
# min                -122.453704        3.000000             37.317298
# ...

# %%
# start with a standard-scaled plot
binsize = 100
bins = np.arange(0, df_bike['duration_sec'].max()+binsize, binsize)

plt.figure(figsize=[8,5])
plt.hist(data = df_bike, x = 'duration_sec', bins = bins)
plt.xlabel('Time')
plt.show()

# %%
# there's a long tail in the distribution, so let's put it on a log scale instead
log_binsize = 0.01
bins = 10 ** np.arange(1.0, np.log10(df_bike['duration_sec'].max())+log_binsize, log_binsize)

plt.figure(figsize = [8,5])
plt.hist(data = df_bike, x = 'duration_sec', bins = bins)
plt.xscale('log')
plt.xticks([1e1, 1e2, 1e3, 1e4, 1e5], [100, '20k', '40k', '60k', '80k'])
plt.xlabel('Time')
plt.show()

# %% [markdown]
# Duration second has a long-tailed distribution, with a lot of small time end, and few on the greatest time end.
# When plotted on a log-scale, the duration seconds distribution looks a normal distribution, with the peak between 20000 and 60000, and its slightly skewed to the right.

# %%
fig, ax = plt.subplots(nrows=3, figsize = [8,15])

variables = ['start_station_id', 'end_station_id', 'bike_id']
for i in range(len(variables)):
    var = variables[i]
    bins = np.arange(min(df_bike[var]), max(df_bike[var])+3, 3)
    ax[i].hist(data = df_bike, x = var, bins = bins)
    ax[i].set_xlabel('{} (mm)'.format(var))

plt.show()

# %% [markdown]
# The initial plot of the start_station_id, end_station_id, and bike_id variables show some immediate points of attention. In all the three variables, there are very large spikes in frequency at the bars with one digit of precision; frequency quickly trails off.

# %%
# plotting bike_id on a standard scale
binsize = 50
bins = np.arange(0, df_bike['bike_id'].max()+binsize, binsize)

plt.figure(figsize=[8, 5])
plt.hist(data = df_bike, x = 'bike_id', bins = bins)
plt.xlabel('bike_id')
plt.show()

# %% [markdown]
# ### Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perform any transformations?
#
# > The duration_sec variable took on a large range of values, so I looked at the data using a log transform. Under the transformation, the data looked normal distribution, with a peak between \$20000 and \$60000, and it is slightly skewed to the right.
#
#
# ### Of the features you investigated, were there any unusual distributions? Did you perform any operations on the data to tidy, adjust, or change the form of the data? If so, why did you do this?
#
# > When investigating the start_station_id, end_station_id, and bike_id variables, a number of outlier points were identified. Overall, these points can be characterized by an inconsistency between the recorded value of depth, and the value that would be derived from using start_station_id, end_station_id, and bike_id. For safety, all of these points were removed from the dataset to move forwards.

# %% [markdown]
# ## Bivariate Exploration

# %%
numeric_vars = ['duration_sec','start_station_id','start_station_latitude','start_station_longitude',
                'end_station_id','end_station_latitude','end_station_longitude','bike_id','member_birth_year']
categoric_vars = ['user_type', 'member_gender','bike_share_for_all_trip']

# %%
# correlation plot
plt.figure(figsize = [8, 5])
sb.heatmap(df_bike[numeric_vars].corr(), annot = True, fmt = '.3f',
           cmap = 'vlag_r', center = 0)
plt.show()

# %%
# plot matrix: sample 500 diamonds so that plots are clearer and they render faster
print("df_bike.shape=",df_bike.shape)
df_bike_samp = df_bike.sample(n=500, replace = False)
print("df_bike_samp.shape=",df_bike_samp.shape)

g = sb.PairGrid(data = df_bike_samp, vars = numeric_vars)
g = g.map_diag(plt.hist, bins = 20);
g.map_offdiag(plt.scatter)
# Out:
# df_bike.shape= (174952, 18)
# df_bike_samp.shape= (500, 18)

# %% [markdown]
# As expected, the numeric variables  are all highly correlated with one another, and all of them are also highly correlated with the duration secods.

# %%
# plot matrix of numeric features against categorical features.
# can use a larger sample since there are fewer plots and they're simpler in nature.

df_bike_samp = df_bike.sample(n=100, replace = False)


def boxgrid(x, y, **kwargs):
    """ Quick hack for creating box plots with seaborn's PairGrid. """
    default_color = sb.color_palette()[0]
    sb.boxplot(x=x, y=y, color=default_color)

plt.figure(figsize = [10, 10])
g = sb.PairGrid(data = df_bike_samp, y_vars = ['duration_sec', 'bike_id'], x_vars = categoric_vars,
                height = 3, aspect = 1.5)
g.map(boxgrid)
plt.show();

# %% [markdown]
# Interestingly, it appears that there are some negative relationships between the categorical variables and the two numeric variables of interest. The bike dataset with the best features (subscriber, female, no) seem to get the lowest duration seconds and bike_id, but also tend to be greatest on average.

# %%
# since there's only three subplots to create, using the full data should be fine.
plt.figure(figsize = [8, 15])

# subplot 1: user_type vs member_gender
plt.subplot(3, 1, 1)
sb.countplot(data = df_bike, x = 'user_type', hue = 'member_gender', palette = 'Blues')

# subplot 2: bike_share_for_all_trip vs. member_gender
ax = plt.subplot(3, 1, 2)
sb.countplot(data = df_bike, x = 'bike_share_for_all_trip', hue = 'member_gender', palette = 'Blues')
ax.legend(ncol = 2) # re-arrange legend to reduce overlapping

# subplot 3: bike_share_for_all_trip vs. user_type, use different color palette
ax = plt.subplot(3, 1, 3)
sb.countplot(data = df_bike, x = 'bike_share_for_all_trip', hue = 'user_type', palette = 'Greens')
ax.legend(loc = 1, ncol = 2) # re-arrange legend to remove overlapping

plt.show()

# %% [markdown]
# There doesn't seem to be that much interaction between df_bike user_id and member_gender, though proportionally it seems like there might be more subscriber *user_type* on the greatest *member_gender* (*male and female*). There are no interactions on *the bike_share_for_all_trip* and *gender_member*, the lower level for both *yes* and *no* is the *other*. It looks like there are more *male* in the member_gender.

# %%
# scatter plot of duration_sec vs. bike_id, with log transform on price axis

plt.figure(figsize = [14, 8])
plt.scatter(data = df_bike, x = 'bike_id', y = 'duration_sec', alpha = 1/10)
plt.xlabel('bike_id')
plt.ylabel('duration_sec')
# Out:
# Text(0, 0.5, 'duration_sec')

# %%
def cuberoot_trans(x, inverse = False):
    """ quick function for computing cube root and cube operations """
    if not inverse:
        return x ** (1/3)
    else:
        return x ** 3

# %%
# compute the logarithm of duration_sec to make multivariate plotting easier
def log_trans(x, inverse = False):
    """ quick function for computing log and power operations """
    if not inverse:
        return np.log10(x)
    else:
        return np.power(10, x)

df_bike['lod_duration_sec'] = df_bike['duration_sec'].apply(log_trans)
df_bike['cr_bike_id'] = df_bike['bike_id'].apply(cuberoot_trans)

# %%
# plot the categorical variables against duration_sec and bike_id again, this time
# with full data and variable transforms
bike_id_ticks = [2, 3, 5, 7, 9, 10, 15, 20]
fig, ax = plt.subplots(ncols = 2, nrows = 3 , figsize = [10,10])

for i in range(len(categoric_vars)):
    var = categoric_vars[i]
    sb.violinplot(data = df_bike, x = var, y = 'lod_duration_sec', ax = ax[i,0],
               color = def_color)
    ax[i,0].set_yticks(log_trans(np.array([500, 1e3, 2e3, 5e3, 1e4, 2e4])))
    ax[i,0].set_yticklabels([500, '1k', '2k', '5k', '10k', '20k'])
    sb.violinplot(data = df_bike, x = var, y = 'cr_bike_id', ax = ax[i,1],
               color = def_color)

plt.show()

# %% [markdown]
# The plot of the full data using a violin plot and variable transformations reveals much more than the earlier box plots. It is highly suggested that the decrease in average duration second across increasing quality is due to the average quality decreasing with increasing quality. This is clearest in the plots across member_gender, moderately visible with user_type and bike_share_for_all_trip.

# %%
sb.pointplot(data=df_bike, x='member_gender', y='duration_sec', color=def_color, errorbar='sd', linestyles="")
plt.xticks(rotation=15);
plt.ylabel('duration_sec')
# Out:
# Text(0, 0.5, 'duration_sec')

# %% [markdown]
# From the graph we could see that, under the member gender column the male had the least duration second indcating the fasters.

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
#
# Interestingly, it appears that there are some negative relationships between the categorical variables and the two numeric variables of interest. The bike dataset with the best features (subscriber, female, no) seem to get the lowest duration seconds and bike_id, but also tend to be greatest on average.
#
# There doesn't seem to be that much interaction between df_bike user_id and member_gender, though proportionally it seems like there might be more subscriber *user_type* on the greatest *member_gender* (*male and female*). There are no interactions on *the bike_share_for_all_trip* and *gender_member*, the lower level for both *yes* and *no* is the *other*. It looks like there are more *male* in the member_gender.
#
# The plot of the full data using a violin plot and variable transformations reveals much more than the earlier box plots. It is highly suggested that the decrease in average duration second across increasing quality is due to the average quality decreasing with increasing quality. This is clearest in the plots across member_gender, moderately visible with user_type and bike_share_for_all_trip.
#
#
# ### Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?
#
# > Expected relationships were found in the association between the subscribe and customer of the user_type of bike dataset. Most of the bike user were subscribers.

# %% [markdown]
# ## Multivariate Exploration
#
# > Create plots of three or more variables to investigate your data even
# further. Make sure that your investigations are justified, and follow from
# your work in the previous sections.

# %%
df_bike[['duration_sec','bike_id']].describe()
# Out:
#         duration_sec        bike_id
# count  174952.000000  174952.000000
# mean      704.002744    4482.587555
# std      1642.204905    1659.195937
# min        61.000000      11.000000
# 25%       323.000000    3799.000000
# 50%       510.000000    4960.000000
# 75%       789.000000    5505.000000
# max     84548.000000    6645.000000

# %%
plt.hist2d(data = df_bike, x = 'duration_sec', y = 'bike_id', cmin=0.5, cmap='viridis_r',)
plt.colorbar()
plt.xlabel('duration_sec')
plt.ylabel('bike_id');

# %%
# Use group_by() and size() to get the number of member_gender and each combination of the two variable
ct_counts = df_bike.groupby(['member_gender', 'bike_share_for_all_trip']).size()
ct_counts
# Out:
# member_gender  bike_share_for_all_trip
# Female         No                          37211
#                Yes                          3594
# Male           No                         117396
#                Yes                         13104
# Other          No                           2999
#                Yes                           648
# dtype: int64

# %%
ct_counts = ct_counts.reset_index(name='count')
ct_counts
# Out:
#   member_gender bike_share_for_all_trip   count
# 0        Female                      No   37211
# 1        Female                     Yes    3594
# 2          Male                      No  117396
# 3          Male                     Yes   13104
# 4         Other                      No    2999
# 5         Other                     Yes     648

# %%
# Use DataFrame.pivot() to rearrange the data, to have vehicle class on rows
ct_counts = ct_counts.pivot(index = 'member_gender', columns = 'bike_share_for_all_trip', values = 'count')
ct_counts
# Out:
# bike_share_for_all_trip      No    Yes
# member_gender
# Female                    37211   3594
# Male                     117396  13104
# Other                      2999    648

# %%
sb.heatmap(ct_counts)
# Out:
# <AxesSubplot:xlabel='bike_share_for_all_trip', ylabel='member_gender'>

# %%
sb.heatmap(ct_counts, annot = True, fmt = 'd')
# Out:
# <AxesSubplot:xlabel='bike_share_for_all_trip', ylabel='member_gender'>

# %% [markdown]
# The heat map show the relationship between bike_share_for_all_trip and member_gender, you can see the relationships as male having the highest section.

# %%
gen_vars = ['Female', 'Male','Other']
vclasses = pd.api.types.CategoricalDtype(ordered=True, categories=gen_vars)
df_bike['member_gender'] = df_bike['member_gender'].astype(vclasses);

# Plot the Seaborn's FacetGrid
g = sb.FacetGrid(data = df_bike, col = 'member_gender')
g.map(plt.hist, "bike_id")

# %%
df_bike_flag = (df_bike['duration_sec'] >= 100) & (df_bike['duration_sec'] <= 1000)
df_bike_sml = df_bike.loc[df_bike_flag,:]

# %%
fig = plt.figure(figsize = [8,6])
ax = sb.pointplot(data = df_bike_sml, x = 'member_gender', y = 'duration_sec', hue = 'bike_share_for_all_trip',
           palette = 'Blues', linestyles = '', dodge = 0.4)
plt.title('')
plt.ylabel('duration_sec')
plt.show();

# %% [markdown]
# We can see how member_gender and duration_sec grades affect GoBike duration second by plotting the average duration second on selected duration seconds: those around 100 duration_sec and those around 1000 duration_sec. For both the 100-duration_sec and 1000-duration_sec GoBike, as the  duration second level increases, the general height of the points rises, showing an increase in duration second.

# %%
df_bike.to_csv("fordgobike-tripdata.csv", index=False)

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. Were there features that strengthened each other in terms of looking at your feature(s) of interest?
#
# > I extended my investigation of duration seconds against bike id in this section by looking at the impact of the of other two variables member gender and bike_share_for_all_trip variable features. The multivariate exploration here showed that there indeed is a positive effect of increased male gender  on duration second.
#
#
# ### Were there any interesting or surprising interactions between features?
#
# > Looking back on the point plots, it doesn't seem like there's a systematic interaction effect between the three variable features. However, the features also aren't fully independent.

# %% [markdown]
# ## Conclusions
# > The bike data set contains male,female and othe under the member gender, but the female had the smallest duration seconds, which makes the female fasters racers.
